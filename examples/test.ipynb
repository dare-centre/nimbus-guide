# %%
import numpy as np
print(np.random.rand(3,3))

# %%
import os
os.getcwd()
# Out:
# '/project/python'

# %%
import psutil
# gives a single float value
print('CPU usage: {}%'.format(psutil.cpu_percent()))
# gives an object with many fields
print(psutil.virtual_memory())
print('Memory Total: {} MB'.format(psutil.virtual_memory().total >> 20))
# you can convert that object to a dictionary 
print(dict(psutil.virtual_memory()._asdict()))
# you can have the percentage of used RAM
print('Mem usage: {:.2f}%'.format(psutil.virtual_memory().percent))
# you can calculate percentage of available memory
print('Avail mem: {:.2f}%'.format(psutil.virtual_memory().available * 100 / psutil.virtual_memory().total))
# Out:
# CPU usage: 0.6%
# svmem(total=33729970176, available=32015904768, percent=5.1, used=1275011072, free=26850238464, active=2286997504, inactive=3938009088, buffers=252538880, cached=5352181760, shared=1118208, slab=532258816)
# Memory Total: 32167 MB
# {'total': 33729970176, 'available': 32015904768, 'percent': 5.1, 'used': 1275011072, 'free': 26850238464, 'active': 2287009792, 'inactive': 3938009088, 'buffers': 252538880, 'cached': 5352181760, 'shared': 1118208, 'slab': 532258816}
# Mem usage: 5.10%
# Avail mem: 94.92%
